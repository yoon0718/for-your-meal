#
# [126675 rows x 21 columns]

# %%
print(len(data.loc[data['labels'] == 'anger']))
print(len(data.loc[data['labels'] == 'disgust']))
print(len(data.loc[data['labels'] == 'fear']))
print(len(data.loc[data['labels'] == 'happiness']))
print(len(data.loc[data['labels'] == 'neutral']))
print(len(data.loc[data['labels'] == 'sadness']))
# Out:
# 34899
# 13980
# 12393
# 13644
# 9786
# 41973

# %%
data1 = data.loc[data['labels'] == 'anger'][:9786]
data2 = data.loc[data['labels'] == 'disgust'][:9786]
data3 = data.loc[data['labels'] == 'fear'][:9786]
data4 = data.loc[data['labels'] == 'happiness'][:9786]
data5 = data.loc[data['labels'] == 'neutral'][:9786]
data6 = data.loc[data['labels'] == 'sadness'][:9786]

# %%
total_data = pd.concat([data1, data2, data3, data4, data5, data6])

# %%
total_data.reset_index(inplace=False)
# Out:
#        index           0           1          2          3          4  \
# 0          0 -415.361755   72.224693   4.757228  22.024660  -7.468746
# 1          1 -397.943008   56.707922  12.668263  15.861688  -1.460216
# 2          2 -484.022614   66.650978   6.307154  16.172136  -6.870571
# 3          3 -394.473877   76.370163   2.615793  16.192711 -16.572311
# 4          4 -340.119416   42.994443  13.547365   5.624892  -5.442980
# ...      ...         ...         ...        ...        ...        ...
# 58711  21397 -252.984951   63.153043   4.040540  -2.363150  -9.909623
# 58712  21398 -406.075592  115.639992  -8.642056   9.230587 -12.310991
# 58713  21426 -317.955658   90.360344 -10.365887   8.286254  -5.905339
# 58714  21427 -267.646434   53.896683  -1.593334   1.922569  -2.460712
# 58715  21428 -382.295654   87.247276 -13.392465   6.795467  -7.771042
#
#               5         6          7          8  ...        11        12  \
# 0      9.577067 -8.639965  15.034519 -23.448441  ... -3.931750 -3.281601
# 1      2.442069 -1.423752   8.054613 -15.955816  ... -7.190061 -0.293290
# 2      5.009261 -7.100348  10.470600 -22.409895  ...  0.951344 -4.016384
# 3      9.222215 -0.099308  18.952885 -27.506077  ... -4.123139 -2.376334
# 4      0.130013  6.555159   6.332881 -11.802520  ... -5.144852  2.253876
# ...         ...       ...        ...        ...  ...       ...       ...
# 58711 -2.922228 -2.502354 -12.844999  -8.444619  ... -8.643914 -6.675053
# 58712  2.875495 -8.832375 -24.322306  -8.718390  ... -7.310768 -5.856149
# 58713 -0.670596  6.858087 -17.610382  -2.092952  ... -6.481479 -1.447810
# 58714 -0.234175  1.547149 -10.401694  -2.707819  ... -7.416027 -1.272164
# 58715  1.858972  3.286209 -18.034824   1.513977  ... -2.717779  1.950562
#
#              13        14        15        16         17        18         19  \
# 0     -1.899613  2.359723  6.410924  4.475190  -4.098377 -1.267751  10.269837
# 1     -4.104114  4.345541  4.430217  5.423108  -5.226371  1.238049   6.735763
# 2      3.554343  4.922379  7.777921  3.526608  -3.229036  6.234205   7.711937
# 3      3.677343 -0.432691  4.290534  7.868842  -6.732822 -4.141521  10.976520
# 4      1.957482  2.292511  2.347049  4.673205  -4.814169 -0.738692   3.942068
# ...         ...       ...       ...       ...        ...       ...        ...
# 58711 -4.750692 -1.180692 -4.450562 -3.009031   1.403742  0.283031   2.246596
# 58712 -2.261326 -1.571590 -8.094721 -0.032093   2.864317  0.482640   5.611249
# 58713  5.774753 -1.708975 -2.965655  4.870959  -8.496428 -9.223205   0.079353
# 58714  3.061306 -0.697446 -0.805314  1.243053  -6.023999 -7.525384  -2.038925
# 58715  6.844234 -6.122221  1.081262  2.012774 -10.176879 -4.003643   1.827749
#
#         labels
# 0        anger
# 1        anger
# 2        anger
# 3        anger
# 4        anger
# ...        ...
# 58711  sadness
# 58712  sadness
# 58713  sadness
# 58714  sadness
# 58715  sadness
#
# [58716 rows x 22 columns]

# %%
X = total_data.iloc[: ,:-1].values
Y = total_data['labels'].values

# %%
np.unique(total_data['labels'].values)
# Out:
# array(['anger', 'disgust', 'fear', 'happiness', 'neutral', 'sadness'],
#       dtype=object)

# %%
np.unique(np.array(total_data['labels'].values))
# Out:
# array(['anger', 'disgust', 'fear', 'happiness', 'neutral', 'sadness'],
#       dtype=object)

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
#케라스 불러오기
import keras
from keras.callbacks import ReduceLROnPlateau
from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization, GlobalAveragePooling1D, LSTM
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint

# %%
# 다중 클래스 분류하기위해 Y설정
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# %%
Y.shape
# Out:
# (58716, 6)

# %%
# 훈련데이터, 테스트데이터 분리
x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state=0, shuffle=True)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((44037, 20), (44037, 6), (14679, 20), (14679, 6))

# %%
# 훈련 및 테스트데이터 갯수 확인
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((44037, 20), (44037, 6), (14679, 20), (14679, 6))

# %%
# 데이터의 차원 모델에 맞게 통일 
x_train = np.expand_dims(x_train, axis=2)
x_test = np.expand_dims(x_test, axis=2)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((44037, 20, 1), (44037, 6), (14679, 20, 1), (14679, 6))

# %%
x_train.shape[0]
# Out:
# 44037

# %%
# version1 - epoch 100
# factor=0.4, verbose=0, patience=5, min_lr=0.0000001
# 

model = Sequential()
model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu', input_shape=(x_train.shape[1], 1)))
model.add(MaxPooling1D(pool_size=5, strides=2, padding='same'))
model.add(Dense(units=128, activation='relu'))  # 추가된 ReLU 활성화 함수를 사용하는 Dense 층

model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides=2, padding='same'))
model.add(Dense(units=128, activation='relu'))  # 추가된 ReLU 활성화 함수를 사용하는 Dense 층

model.add(Conv1D(128, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides=2, padding='same'))
model.add(Dropout(0.2))

model.add(Conv1D(64, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides=2, padding='same'))
model.add(LSTM(256, return_sequences=True))
model.add(Flatten())
model.add(Dense(units=32, activation='relu'))
model.add(Dropout(0.6))

model.add(Dense(units=6, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 20, 256)           1536
#
#  max_pooling1d_4 (MaxPooling  (None, 10, 256)          0
#  1D)
#
#  dense_4 (Dense)             (None, 10, 128)           32896
#
#  conv1d_5 (Conv1D)           (None, 10, 256)           164096
#
#  max_pooling1d_5 (MaxPooling  (None, 5, 256)           0
#  1D)
#
#  dense_5 (Dense)             (None, 5, 128)            32896
#
#  conv1d_6 (Conv1D)           (None, 5, 128)            82048
#
#  max_pooling1d_6 (MaxPooling  (None, 3, 128)           0
#  1D)
#
#  dropout_2 (Dropout)         (None, 3, 128)            0
#
#  conv1d_7 (Conv1D)           (None, 3, 64)             41024
#
#  max_pooling1d_7 (MaxPooling  (None, 2, 64)            0
#  1D)
#
#  lstm_1 (LSTM)               (None, 2, 256)            328704
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_6 (Dense)             (None, 32)                16416
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_7 (Dense)             (None, 6)                 198
#
# =================================================================
# Total params: 699,814
# Trainable params: 699,814
# Non-trainable params: 0
# _________________________________________________________________

# %%
rlrp = ReduceLROnPlateau(monitor='loss', factor=0.4, verbose=0, patience=5, min_lr=0.0000001)
history=model.fit(x_train, y_train, batch_size=64, epochs=100, validation_data=(x_test, y_test), callbacks=[rlrp])
# Out:
# Epoch 1/100
# 689/689 [==============================] - 10s 12ms/step - loss: 1.7571 - accuracy: 0.2151 - val_loss: 1.7018 - val_accuracy: 0.2571 - lr: 0.0010
# Epoch 2/100
# 689/689 [==============================] - 7s 11ms/step - loss: 1.7000 - accuracy: 0.2556 - val_loss: 1.6563 - val_accuracy: 0.2924 - lr: 0.0010
# Epoch 3/100
# 689/689 [==============================] - 7s 10ms/step - loss: 1.6754 - accuracy: 0.2731 - val_loss: 1.6240 - val_accuracy: 0.3051 - lr: 0.0010
# Epoch 4/100
# 689/689 [==============================] - 7s 11ms/step - loss: 1.6524 - accuracy: 0.2890 - val_loss: 1.6166 - val_accuracy: 0.3102 - lr: 0.0010
# Epoch 5/100
# 689/689 [==============================] - 8s 11ms/step - loss: 1.6369 - accuracy: 0.2980 - val_loss: 1.5983 - val_accuracy: 0.3234 - lr: 0.0010
# Epoch 6/100
# 689/689 [==============================] - 7s 11ms/step - loss: 1.6203 - accuracy: 0.3072 - val_loss: 1.5841 - val_accuracy: 0.3336 - lr: 0.0010
# Epoch 7/100
# 689/689 [==============================] - 7s 11ms/step - loss: 1.5992 - accuracy: 0.3203 - val_loss: 1.5614 - val_accuracy: 0.3369 - lr: 0.0010
# Epoch 8/100
# 689/689 [==============================] - 7s 11ms/step - loss: 1.5783 - accuracy: 0.3307 - val_loss: 1.5496 - val_accuracy: 0.3457 - lr: 0.0010
# Epoch 9/100
# 689/689 [==============================] - 8s 11ms/step - loss: 1.5620 - accuracy: 0.3397 - val_loss: 1.5401 - val_accuracy: 0.3530 - lr: 0.0010
# Epoch 10/100
# 689/689 [==============================] - 8s 12ms/step - loss: 1.5447 - accuracy: 0.3501 - val_loss: 1.5375 - val_accuracy: 0.3525 - lr: 0.0010
# Epoch 11/100
# 689/689 [==============================] - 8s 11ms/step - loss: 1.5280 - accuracy: 0.3560 - val_loss: 1.5377 - val_accuracy: 0.3537 - lr: 0.0010
# Epoch 12/100
# 689/689 [==============================] - 9s 12ms/step - loss: 1.5110 - accuracy: 0.3615 - val_loss: 1.5161 - val_accuracy: 0.3653 - lr: 0.0010
# Epoch 13/100
# 689/689 [==============================] - 8s 12ms/step - loss: 1.4885 - accuracy: 0.3756 - val_loss: 1.5156 - val_accuracy: 0.3670 - lr: 0.0010
# Epoch 14/100
# 689/689 [==============================] - 9s 12ms/step - loss: 1.4712 - accuracy: 0.3810 - val_loss: 1.5087 - val_accuracy: 0.3703 - lr: 0.0010
# Epoch 15/100
# 689/689 [==============================] - 8s 12ms/step - loss: 1.4575 - accuracy: 0.3912 - val_loss: 1.4969 - val_accuracy: 0.3763 - lr: 0.0010
# Epoch 16/100
# 689/689 [==============================] - 8s 12ms/step - loss: 1.4407 - accuracy: 0.3956 - val_loss: 1.4860 - val_accuracy: 0.3824 - lr: 0.0010
# Epoch 17/100
# 689/689 [==============================] - 9s 13ms/step - loss: 1.4178 - accuracy: 0.4072 - val_loss: 1.5107 - val_accuracy: 0.3758 - lr: 0.0010
# Epoch 18/100
# 689/689 [==============================] - 9s 13ms/step - loss: 1.3936 - accuracy: 0.4150 - val_loss: 1.4858 - val_accuracy: 0.3897 - lr: 0.0010
# Epoch 19/100
# 689/689 [==============================] - 8s 12ms/step - loss: 1.3759 - accuracy: 0.4246 - val_loss: 1.4932 - val_accuracy: 0.3867 - lr: 0.0010
# Epoch 20/100
# 689/689 [==============================] - 8s 12ms/step - loss: 1.3691 - accuracy: 0.4266 - val_loss: 1.4920 - val_accuracy: 0.3959 - lr: 0.0010
# Epoch 21/100
# 689/689 [==============================] - 8s 12ms/step - loss: 1.3454 - accuracy: 0.4347 - val_loss: 1.4889 - val_accuracy: 0.3932 - lr: 0.0010
# Epoch 22/100
# 689/689 [==============================] - 8s 12ms/step - loss: 1
100
# 689/689 [==============================] - 8s 11ms/step - loss: 0.6967 - accuracy: 0.7176 - val_loss: 2.3214 - val_accuracy: 0.4335 - lr: 0.0010
# Epoch 90/100
# 689/689 [==============================] - 8s 11ms/step - loss: 0.7042 - accuracy: 0.7171 - val_loss: 2.4530 - val_accuracy: 0.4343 - lr: 0.0010
# Epoch 91/100
# 689/689 [==============================] - 8s 11ms/step - loss: 0.7433 - accuracy: 0.7007 - val_loss: 2.2674 - val_accuracy: 0.4365 - lr: 0.0010
# Epoch 92/100
# 689/689 [==============================] - 8s 11ms/step - loss: 0.7047 - accuracy: 0.7142 - val_loss: 2.3057 - val_accuracy: 0.4376 - lr: 0.0010
# Epoch 93/100
# 689/689 [==============================] - 8s 11ms/step - loss: 0.7062 - accuracy: 0.7190 - val_loss: 2.2362 - val_accuracy: 0.4241 - lr: 0.0010
# Epoch 94/100
# 689/689 [==============================] - 8s 11ms/step - loss: 0.6928 - accuracy: 0.7212 - val_loss: 2.4105 - val_accuracy: 0.4357 - lr: 0.0010
# Epoch 95/100
# 689/689 [==============================] - 8s 11ms/step - loss: 0.6859 - accuracy: 0.7267 - val_loss: 2.3050 - val_accuracy: 0.4301 - lr: 0.0010
# Epoch 96/100
# 689/689 [==============================] - 8s 11ms/step - loss: 0.7010 - accuracy: 0.7231 - val_loss: 2.3824 - val_accuracy: 0.4348 - lr: 0.0010
# Epoch 97/100
# 689/689 [==============================] - 7s 11ms/step - loss: 0.6825 - accuracy: 0.7270 - val_loss: 1.9812 - val_accuracy: 0.4178 - lr: 0.0010
# Epoch 98/100
# 689/689 [==============================] - 7s 11ms/step - loss: 0.6921 - accuracy: 0.7249 - val_loss: 2.4388 - val_accuracy: 0.4333 - lr: 0.0010
# Epoch 99/100
# 689/689 [==============================] - 7s 11ms/step - loss: 0.6974 - accuracy: 0.7246 - val_loss: 2.2836 - val_accuracy: 0.4324 - lr: 0.0010
# Epoch 100/100
# 689/689 [==============================] - 8s 11ms/step - loss: 0.6912 - accuracy: 0.7290 - val_loss: 2.4810 - val_accuracy: 0.4303 - lr: 0.0010

# %%
model.save("sound_classifier_model_MFCC(version1).h5")

# %%
from keras.models import load_model

# %%
import matplotlib.pyplot as plt

# %%
print("Accuracy of our model on test data : " , model.evaluate(x_test,y_test)[1]*100 , "%")

epochs = [i for i in range(1000)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
test_acc = history.history['val_accuracy']
test_loss = history.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()
# Out:
# 689/689 [==============================] - 3s 4ms/step - loss: 2.1051 - accuracy: 0.3237
# Accuracy of our model on test data :  32.36989080905914 %

# %%
x_test.shape
# Out:
# (22039, 20, 1)

# %%
# 테스트데이터 적용
pred_test = model.predict(x_test)
pred_test
y_pred = encoder.inverse_transform(pred_test)
y_test2 = encoder.inverse_transform(y_test)
# Out:
# 689/689 [==============================] - 2s 2ms/step

# %%
df = pd.DataFrame(columns=['Predicted Labels', 'Actual Labels'])
df['Predicted Labels'] = y_pred.flatten()
df['Actual Labels'] = y_test2.flatten()

df.head(3)
# Out:
#   Predicted Labels Actual Labels
# 0          sadness       sadness
# 1          sadness     happiness
# 2          neutral       sadness

# %%
import seaborn as sns

# %%
cm = confusion_matrix(y_test2, y_pred)
plt.figure(figsize = (12, 10))
cm = pd.DataFrame(cm , index = [i for i in encoder.categories_] , columns = [i for i in encoder.categories_])
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True, fmt='')
plt.title('Confusion Matrix', size=20)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()

# %%
print(classification_report(y_test2, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.33      0.18      0.23      4864
#      disgust       0.20      0.01      0.02      2365
#         fear       0.32      0.01      0.03      1877
#    happiness       0.42      0.12      0.18      3386
#      neutral       0.26      0.44      0.33      3810
#      sadness       0.34      0.72      0.47      5737
#
#     accuracy                           0.32     22039
#    macro avg       0.31      0.25      0.21     22039
# weighted avg       0.32      0.32      0.26     22039

# %%
model.evaluate(x_test, y_test, batch_size=128)
# Out:
# 173/173 [==============================] - 1s 4ms/step - loss: 1.7246 - accuracy: 0.3220
# [1.7246055603027344, 0.3220200538635254]
